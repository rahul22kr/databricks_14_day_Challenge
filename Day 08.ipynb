# %%
# %sql
-- Create structure
CREATE CATALOG ecommerce;
USE CATALOG ecommerce;
CREATE SCHEMA bronze;
CREATE SCHEMA silver;
CREATE SCHEMA gold;

# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.bronze.events
USING DELTA
AS
SELECT * FROM workspace.bronze.ecommerce_data

# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.silver.events
USING DELTA
AS
SELECT * FROM workspace.Silver.ecommerce_data

# %%
# %sql
CREATE TABLE IF NOT EXISTS ecommerce.gold.events
USING DELTA
AS
SELECT * FROM workspace.Glod.ecommerce_data

# %% [markdown]
# ### Creating Views

# %%
# %sql
create view a
as
select * from workspace.bronze.ecommerce_data

# %%
# %sql
select * from a
